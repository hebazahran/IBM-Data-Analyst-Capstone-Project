# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ------------------------------------ 292.8/292.8 kB 696.0 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.2)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#      ---------------------------------------- 36.9/36.9 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\heba zahran\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.1 seaborn-0.11.2
# WARNING: There was an error checking the latest version of pip.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df.dropna(subset=["ConvertedComp"], axis=0, inplace=True)
df['ConvertedComp'].value_counts().head(20)
# Out:
# 2000000.0    138
# 1000000.0    105
# 100000.0      99
# 150000.0      92
# 120000.0      86
# 110000.0      83
# 70000.0       81
# 130000.0      77
# 90000.0       77
# 80000.0       73
# 68745.0       71
# 140000.0      68
# 57287.0       68
# 85000.0       67
# 125000.0      65
# 60000.0       64
# 54996.0       62
# 105000.0      58
# 95000.0       58
# 45830.0       55
# Name: ConvertedComp, dtype: int64

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
plt.figure(figsize=(12, 7))

sns.distplot(df['ConvertedComp'], hist=False, color="r")

plt.title('Distribution of Developers\' Annual Salary in USD')
plt.xlabel('Salary converted to annual USD (exchange rate 2019-02-01)')
plt.ylabel('Proportion of Respondents')

plt.show()
plt.close()
# Out:
# C:\Users\Heba Zahran\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
count, bin_edges = np.histogram(df['ConvertedComp'])

print(count) # frequency count
print(bin_edges) # bin ranges, default = 10 bins
df['ConvertedComp'].plot(kind='hist', figsize=(20, 5), xticks=bin_edges)

plt.title('Histogram of distribution of Developers\' Annual Salary in USD') # add a title to the histogram
plt.ylabel('Number of Respondents') # add y-label
plt.xlabel('Annual Salary in USD') # add x-label

plt.show()
# Out:
# [9659  238  115  125   99  131   34   15   15  151]
# [      0.  200000.  400000.  600000.  800000. 1000000. 1200000. 1400000.
#  1600000. 1800000. 2000000.]

# %%
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df[df['Gender'] == 'Man'].shape[0]
# Out:
# 9725

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df['ConvertedComp'][df['Gender'] == 'Woman'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df.dropna(subset=["Age"], axis=0, inplace=True)
df['Age'].describe()
# Out:
# count    10354.000000
# mean        30.833040
# std          7.389983
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df['Age'].median()
# Out:
# 29.0

# %%
df['Age'].plot(kind='box', figsize=(8, 10))

plt.title('Box plot of Developers\' Age')
plt.ylabel('Age')

plt.show()

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
count, bin_edges = np.histogram(df['Age'])
print(count)
print(bin_edges)
df['Age'].plot(kind='hist', figsize=(12,7), xticks=bin_edges)
plt.title("Histogram of Developers\' Age WorldWide")
plt.ylabel("Number of Respondents")
plt.xlabel("Age")

plt.show()
# Out:
# [1929 4968 2406  788  210   48    4    0    0    1]
# [16.  24.3 32.6 40.9 49.2 57.5 65.8 74.1 82.4 90.7 99. ]

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df['ConvertedComp'].plot(kind='box', figsize=(8, 10))

plt.title('Box plot of Developers\' Annual Salary in USD')
plt.ylabel('Number of Respondents')

plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].describe()
# Q1(25%) = 2.683450e+04
# Q3(75%) = 1.000000e+05
# IQR = Q3 - Q1 = 1.000000e+05 - 2.683450e+04 = 73,165.5
# Out:
# count    1.035400e+04
# mean     1.313593e+05
# std      2.939787e+05
# min      0.000000e+00
# 25%      2.683450e+04
# 50%      5.760000e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
IQR = df['ConvertedComp'].describe()[6] - df['ConvertedComp'].describe()[4]
IQR
# Out:
# 73165.5

# %%
IQR_V = 1.5 * IQR
IQR_V
# Out:
# 109748.25

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
lower = df['ConvertedComp'].describe()[4] - IQR_V
upper = df['ConvertedComp'].describe()[6] + IQR_V

print("Lower bound is:" , lower)
print("Upper bound is:" , upper)
# Out:
# Lower bound is: -82913.75
# Upper bound is: 209748.25

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
# Using the definition of outlier, any value that is greater than Q3 by 1.5 times or lower than Q1 1.5 times IQR will be flagged as outlier.
# Outlier > 1.000000e+05 + (1.5 * 73,165.5)
# Outlier > 209,748.25

df[(df['ConvertedComp'] > upper) | (df['ConvertedComp'] < lower)].shape[0]
# Out:
# 861

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df_new = df[df['ConvertedComp'] <= upper]
# df_new.drop(['level_0', 'index'], axis=1, inplace=True)
df_new.median()
# Out:
# C:\Users\Heba Zahran\AppData\Local\Temp\ipykernel_20792\1315559511.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_new.median()
# Respondent       12590.0
# CompTotal        62500.0
# ConvertedComp    52356.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df_new.mean()
# Out:
# C:\Users\Heba Zahran\AppData\Local\Temp\ipykernel_20792\1212866955.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_new.mean()
# Respondent        12519.288844
# CompTotal        732163.544190
# ConvertedComp     59740.170441
# WorkWeekHrs          41.895104
# CodeRevHrs            4.717439
# Age                  30.695860
# dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df_new.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019281       0.010916    -0.017491    0.004692
# CompTotal       -0.019281   1.000000      -0.063574     0.004667    0.015992
# ConvertedComp    0.010916  -0.063574       1.000000     0.033110   -0.086527
# WorkWeekHrs     -0.017491   0.004667       0.033110     1.000000    0.038948
# CodeRevHrs       0.004692   0.015992      -0.086527     0.038948    1.000000
# Age              0.002180   0.006337       0.401821     0.032032   -0.012878
#
#                     Age
# Respondent     0.002180
# CompTotal      0.006337
# ConvertedComp  0.401821
# WorkWeekHrs    0.032032
# CodeRevHrs    -0.012878
# Age            1.000000

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
